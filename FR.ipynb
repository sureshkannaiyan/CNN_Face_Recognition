# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
import cv2
from CNN_pack import CNN_pack
import pickle
from sklearn.svm import SVC
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
loaded_model = pickle.load(open('SVM_model_50.sav', 'rb'))

# %%
names = ['Aakash', 'Ahad', 'Anirudha', 'Ankita', 'Archana', 'Ashwin', 'Dhruv', 'Ishani', 'Manish', 'Meera', 'Neha', 'Noufan', 'Pooja', 'Praveen', 'Raj', 'Rohit', 'Shital', 'Shraddha', 'Siddharth', 'Smitha', 'Sneha', 'Suhas', 'Suresh', 'Taranjit', 'Tushar', 'Umesh', 'Vaibhav']

# %%
img = cv2.imread('Rohit.jpg')
img_g = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_g = cv2.resize(img_g, (100, 100))
TestF = CNN_pack.CNN(img_g)

# %%
print("Hello", names[int(loaded_model.predict([TestF]))])
imgplot = plt.imshow(img)
plt.show()
# Out:
# Hello Rohit

# %%
# TestF = CNN_pack.CNN(img_g)
# print(loaded_model.predict([TestF]))

# %%
# # # img=mpimg.imread('suresh.jpg')
# imgplot = plt.imshow(img_g)
# plt.show()
